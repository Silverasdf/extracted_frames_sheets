# %% [markdown]
# # Commercial LLM Ground Truth
#
# This notebook is meant to try and ground truth videos using Gemini 2.5

# %%
# Variables to tweak

# API Config

max_tokens = 99999

image_resize = 768

video_width, video_height = 1280, 720 

video_folder = './videos'
sequences_folder = './sequences' # Used to make the videos
output_file = './outputs/ground_truths/gemini_generated_ground_truths.json'

#There is also the prompt messages which is later on in the file
message = '''This is demo only. not real. do your best. These frames are captured for a potential traffic incident. Give me quanitative information whenever possible. Give me the following and number each answer:
              Number of vehicles in accident in a number,
              Accident Type such as t-bone, rear end, etc,
              Person Injury yes or no,
              Need for ambulance yes or no,
              Need for firetruck yes or no,
              Need for Police yes or no,
              Types of vehicles involved, such as suv, truck, sedan,
              Fire yes or no,
              Day/night and weather, such as clear, etc,
              Low Res/Bad Footage yes or no.
              Please ignore any context before these images and this prompt
  '''

# %%
from IPython.display import display, clear_output, Markdown
import base64
from openai import OpenAI
import os
import cv2  # OpenCV is used for image encoding

import pathlib
import textwrap

from google import genai

import PIL.Image
from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from PIL import Image
from IPython import display
import numpy as np
from typing import List
import json
from google.genai import types

# %%
#Turn sequences of images into a video

def make_video_from_images(image_folder: str, video_name: str, fps: int = 30) -> None:
    images = []
    for file in os.listdir(image_folder):
        if file.endswith(('.png', '.jpg', '.jpeg')):
            images.append(os.path.join(image_folder, file))

    #Sort the images by their filename as an integer (i.e. 0.jpg, 1.jpg, 2.jpg, ...)
    images = sorted(images, key=lambda x: int(os.path.splitext(os.path.basename(x))[0]))

    if not images:
        print("No images found.")
        return

    # Create a video from the images
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(video_name, fourcc, fps, (video_width, video_height))

    for image in images:
        frame = cv2.imread(image)
        frame = cv2.resize(frame, (video_width, video_height))
        video.write(frame)

    video.release()
    print(f"Video saved as {video_name}")

for sequence in os.listdir(sequences_folder):
    print(f"Making video {os.path.join(video_folder, sequence) + '.mp4'}")
    if not os.path.exists(os.path.join(video_folder, sequence) + '.mp4'):
        make_video_from_images(os.path.join(sequences_folder, sequence), os.path.join(video_folder, f"{sequence}.mp4"), fps=60)
    else:
        print(f"Video {os.path.join(video_folder, sequence)} exists. Skipping video creation for this sequence.")
# Out:
# Making video ./videos\000000.mp4
# Video ./videos\000000 exists. Skipping video creation for this sequence.
# Making video ./videos\000001.mp4
# Video ./videos\000001 exists. Skipping video creation for this sequence.
# Making video ./videos\000002.mp4
# Video ./videos\000002 exists. Skipping video creation for this sequence.
# Making video ./videos\000003.mp4
# Video ./videos\000003 exists. Skipping video creation for this sequence.
# Making video ./videos\000004.mp4
# Video ./videos\000004 exists. Skipping video creation for this sequence.
# Making video ./videos\000005.mp4
# Video ./videos\000005 exists. Skipping video creation for this sequence.
# Making video ./videos\000006.mp4
# Video ./videos\000006 exists. Skipping video creation for this sequence.
# Making video ./videos\000007.mp4
# Video ./videos\000007 exists. Skipping video creation for this sequence.
# Making video ./videos\000008.mp4
# Video ./videos\000008 exists. Skipping video creation for this sequence.
# Making video ./videos\000009.mp4
# Video ./videos\000009 exists. Skipping video creation for this sequence.
# Making video ./videos\000010.mp4
# Video ./videos\000010 exists. Skipping video creation for this sequence.
# Making video ./videos\000011.mp4
# Video ./videos\000011 exists. Skipping video creation for this sequence.
# Making video ./videos\000012.mp4
# Video ./videos\000012 exists. Skipping video creation for this sequence.
# Making video ./videos\000013.mp4
# Video ./videos\000013 exists. Skipping video creation for this sequence.
# Making video ./videos\000014.mp4
# Video ./videos\000014 exists. Skipping video creation for this sequence.
# Making video ./videos\000015.mp4
# Video ./videos\000015 exists. Skipping video creation for this sequence.
# Making video ./videos\000016.mp4
# Video ./videos\000016 exists. Skipping video creation for this sequence.
# Making video ./videos\000017.mp4
# Video ./videos\000017 exists. Skipping video creation for this sequence.
# Making video ./videos\000018.mp4
# Video ./videos\000018 exists. Skipping video creation for this sequence.
# Making video ./videos\000019.mp4
# Video ./videos\000019 exists. Skipping video creation for this sequence.
# Making video ./videos\000020.mp4
# Video ./videos\000020 exists. Skipping video creation for this sequence.
# Making video ./videos\000021.mp4
# Video ./videos\000021 exists. Skipping video creation for this sequence.
# Making video ./videos\000022.mp4
# Video ./videos\000022 exists. Skipping video creation for this sequence.
# Making video ./videos\000023.mp4
# Video ./videos\000023 exists. Skipping video creation for this sequence.
# Making video ./videos\000024.mp4
# Video ./videos\000024 exists. Skipping video creation for this sequence.
# Making video ./videos\000025.mp4
# Video ./videos\000025 exists. Skipping video creation for this sequence.
# Making video ./videos\000026.mp4
# Video ./videos\000026 exists. Skipping video creation for this sequence.
# Making video ./videos\000027.mp4
# Video ./videos\000027 exists. Skipping video creation for this sequence.
# Making video ./videos\000028.mp4
# Video ./videos\000028 exists. Skipping video creation for this sequence.
# Making video ./videos\000029.mp4
# Video ./videos\000029 exists. Skipping video creation for this sequence.
# Making video ./videos\000030.mp4
# Video ./videos\000030 exists. Skipping video creation for this sequence.
# Making video ./videos\000031.mp4
# Video ./videos\000031 exists. Skipping video creation for this sequence.
# Making video ./videos\000032.mp4
# Video ./videos\000032 exists. Skipping video creation for this sequence.
# Making video ./videos\000033.mp4
# Video ./videos\000033 exists. Skipping video creation for this sequence.
# Making video ./videos\000034.mp4
# Video ./videos\000034 exists. Skipping video creation for this sequence.
# Making video ./videos\000035.mp4
# Video ./videos\000035 exists. Skipping video creation for this sequence.
# Making video ./videos\000036.mp4
# Video ./videos\000036 exists. Skipping video creation for this sequence.
# Making video ./videos\000037.mp4
# Video ./videos\000037 exists. Skipping video creation for this sequence.
# Making video ./videos\000038.mp4
# Video ./videos\000038 exists. Skipping video creation for this sequence.
# Making video ./videos\000039.mp4
# Video ./videos\000039 exists. Skipping video creation for this sequence.
# Making video ./videos\000040.mp4
# Video ./videos\000040 exists. Skipping video creation for this sequence.
# Making video ./videos\000041.mp4
# Video ./videos\000041 exists. Skipping video creation for this sequence.
# Making video ./videos\000042.mp4
# Video ./videos\000042 exists. Skipping video creation for this sequence.
# Making video ./videos\000043.mp4
# Video ./videos\000043 exists. Skipping video creation for this sequence.
# Making video ./videos\000044.mp4
# Video ./videos\000044 exists. Skipping video creation for this sequence.
# Making video ./videos\000045.mp4
# Video ./videos\000045 exists. Skipping video creation for this sequence.
# Making video ./videos\000046.mp4
# Video ./videos\000046 exists. Skipping video creation for this sequence.
# Making video ./videos\000047.mp4
# Video ./videos\000047 exists. Skipping video creation for this sequence.
# Making video ./videos\000048.mp4
# Video ./videos\000048 exists. Skipping video creation for this sequence.
# Making video ./videos\000049.mp4
# Video ./videos\000049 exists. Skipping video creation for this sequence.
# Making video ./videos\000050.mp4
# Video ./videos\000050 exists. Skipping video creation for this sequence.
# Making video ./videos\000051.mp4
# Video ./videos\000051 exists. Skipping video creation for this sequence.
# Making video ./videos\000052.mp4
# Video ./videos\000052 exists. Skipping video creation for this sequence.
# Making video ./videos\000053.mp4
# Video ./videos\000053 exists. Skipping video creation for this sequence.
# Making video ./videos\000054.mp4
# Video ./videos\000054 exists. Skipping video creation for this sequence.
# Making video ./videos\000055.mp4
# Video ./videos\000055 exists. Skipping video creation for this sequence.
# Making video ./videos\000056.mp4
# Video ./videos\000056 exists. Skipping video creation for this sequence.
# Making video ./videos\000057.mp4
# Video ./videos\000057 exists. Skipping video creation for this sequence.
# Making video ./videos\000058.mp4
# Video ./videos\000058 exists. Skipping video creation for this sequence.
# Making video ./videos\000059.mp4
# Video ./videos\000059 exists. Skipping video creation for this sequence.
# Making video ./videos\000060.mp4
# Video ./videos\000060 exists. Skipping video creation for this sequence.
# Making video ./videos\000061.mp4
# Video ./videos\000061 exists. Skipping video creation for this sequence.
# Making video ./videos\000062.mp4
# Video ./videos\000062 exists. Skipping video creation for this sequence.
# Making video ./videos\000063.mp4
# Video ./videos\000063 exists. Skipping video creation for this sequence.
# Making video ./videos\000064.mp4
# Video ./videos\000064 exists. Skipping video creation for this sequence.
# Making video ./videos\000065.mp4
# Video ./videos\000065 exists. Skipping video creation for this sequence.
# Making video ./videos\000066.mp4
# Video ./videos\000066 exists. Skipping video creation for this sequence.
# Making video ./videos\000067.mp4
# Video ./videos\000067 exists. Skipping video creation for this sequence.
# Making video ./videos\000068.mp4
# Video ./videos\000068 exists. Skipping video creation for this sequence.
# Making video ./videos\000069.mp4
# Video ./videos\000069 exists. Skipping video creation for this sequence.
# Making video ./videos\000070.mp4
# Video ./videos\000070 exists. Skipping video creation for this sequence.
# Making video ./videos\000071.mp4
# Video ./videos\000071 exists. Skipping video creation for this sequence.
# Making video ./videos\000072.mp4
# Video ./videos\000072 exists. Skipping video creation for this sequence.
# Making video ./videos\000073.mp4
# Video ./videos\000073 exists. Skipping video creation for this sequence.
# Making video ./videos\000074.mp4
# Video ./videos\000074 exists. Skipping video creation for this sequence.
# Making video ./videos\000075.mp4
# Video ./videos\000075 exists. Skipping video creation for this sequence.
# Making video ./videos\000076.mp4
# Video ./videos\000076 exists. Skipping video creation for this sequence.
# Making video ./videos\000077.mp4
# Video ./videos\000077 exists. Skipping video creation for this sequence.
# Making video ./videos\000078.mp4
# Video ./videos\000078 exists. Skipping video creation for this sequence.
# Making video ./videos\000079.mp4
# Video ./videos\000079 exists. Skipping video creation for this sequence.
# Making video ./videos\000080.mp4
# Video ./videos\000080 exists. Skipping video creation for this sequence.
# Making video ./videos\000081.mp4
# Video ./videos\000081 exists. Skipping video creation for this sequence.
# Making video ./videos\000082.mp4
# Video ./videos\000082 exists. Skipping video creation for this sequence.
# Making video ./videos\000083.mp4
# Video ./videos\000083 exists. Skipping video creation for this sequence.
# Making video ./videos\000084.mp4
# Video ./videos\000084 exists. Skipping video creation for this sequence.
# Making video ./videos\000085.mp4
# Video ./videos\000085 exists. Skipping video creation for this sequence.
# Making video ./videos\000086.mp4
# Video ./videos\000086 exists. Skipping video creation for this sequence.
# Making video ./videos\000087.mp4
# Video ./videos\000087 exists. Skipping video creation for this sequence.
# Making video ./videos\000088.mp4
# Video ./videos\000088 exists. Skipping video creation for this sequence.
# Making video ./videos\000089.mp4
# Video ./videos\000089 exists. Skipping video creation for this sequence.
# Making video ./videos\000090.mp4
# Video ./videos\000090 exists. Skipping video creation for this sequence.
# Making video ./videos\000091.mp4
# Video ./videos\000091 exists. Skipping video creation for this sequence.
# Making video ./videos\000092.mp4
# Video ./videos\000092 exists. Skipping video creation for this sequence.
# Making video ./videos\000093.mp4
# Video ./videos\000093 exists. Skipping video creation for this sequence.
# Making video ./videos\000094.mp4
# Video ./videos\000094 exists. Skipping video creation for this sequence.
# Making video ./videos\000095.mp4
# Video ./videos\000095 exists. Skipping video creation for this sequence.
# Making video ./videos\000096.mp4
# Video ./videos\000096 exists. Skipping video creation for this sequence.
# Making video ./videos\000097.mp4
# Video ./videos\000097 exists. Skipping video creation for this sequence.
# Making video ./videos\000098.mp4
# Video ./videos\000098 exists. Skipping video creation for this sequence.
# Making video ./videos\000099.mp4
# Video ./videos\000099 exists. Skipping video creation for this sequence.
# Making video ./videos\000100.mp4
# Video ./videos\000100 exists. Skipping video creation for this sequence.
# Making video ./videos\000101.mp4
# Video ./videos\000101 exists. Skipping video creation for this sequence.
# Making video ./videos\000102.mp4
# Video ./videos\000102 exists. Skipping video creation for this sequence.
# Making video ./videos\000103.mp4
# Video ./videos\000103 exists. Skipping video creation for this sequence.
# Making video ./videos\000104.mp4
# Video ./videos\000104 exists. Skipping video creation for this sequence.
# Making video ./videos\000105.mp4
# Video ./videos\000105 exists. Skipping video creation for this sequence.
# Making video ./videos\000106.mp4
# Video ./videos\000106 exists. Skipping video creation for this sequence.
# Making video ./videos\000107.mp4
# Video ./videos\000107 exists. Skipping video creation for this sequence.
# Making video ./videos\000108.mp4
# Video ./videos\000108 exists. Skipping video creation for this sequence.
# Making video ./videos\000109.mp4
# Video ./videos\000109 exists. Skipping video creation for this sequence.
# Making video ./videos\000110.mp4
# Video ./videos\000110 exists. Skipping video creation for this sequence.
# Making video ./videos\000111.mp4
# Video ./videos\000111 exists. Skipping video creation for this sequence.
# Making video ./videos\000112.mp4
# Video ./videos\000112 exists. Skipping video creation for this sequence.
# Making video ./videos\000113.mp4
# Video ./videos\000113 exists. Skipping video creation for this sequence.
# Making video ./videos\000114.mp4
# Video ./videos\000114 exists. Skipping video creation for this sequence.
# Making video ./videos\000115.mp4
# Video ./videos\000115 exists. Skipping video creation for this sequence.
# Making video ./videos\000116.mp4
# Video ./videos\000116 exists. Skipping video creation for this sequence.
# Making video ./videos\000117.mp4
# Video ./videos\000117 exists. Skipping video creation for this sequence.
# Making video ./videos\000118.mp4
# Video ./videos\000118 exists. Skipping video creation for this sequence.
# Making video ./videos\000119.mp4
# Video ./videos\000119 exists. Skipping video creation for this sequence.
# Making video ./videos\000120.mp4
# Video ./videos\000120 exists. Skipping video creation for this sequence.
# Making video ./videos\000121.mp4
# Video ./videos\000121 exists. Skipping video creation for this sequence.
# Making video ./videos\000122.mp4
# Video ./videos\000122 exists. Skipping video creation for this sequence.
# Making video ./videos\000123.mp4
# Video ./videos\000123 exists. Skipping video creation for this sequence.
# Making video ./videos\000124.mp4
# Video ./videos\000124 exists. Skipping video creation for this sequence.
# Making video ./videos\000125.mp4
# Video ./videos\000125 exists. Skipping video creation for this sequence.
# Making video ./videos\000126.mp4
# Video ./videos\000126 exists. Skipping video creation for this sequence.
# Making video ./videos\000127.mp4
# Video ./videos\000127 exists. Skipping video creation for this sequence.
# Making video ./videos\000128.mp4
# Video ./videos\000128 exists. Skipping video creation for this sequence.
# Making video ./videos\000129.mp4
# Video ./videos\000129 exists. Skipping video creation for this sequence.
# Making video ./videos\000130.mp4
# Video ./videos\000130 exists. Skipping video creation for this sequence.
# Making video ./videos\000131.mp4
# Video ./videos\000131 exists. Skipping video creation for this sequence.
# Making video ./videos\000132.mp4
# Video ./videos\000132 exists. Skipping video creation for this sequence.
# Making video ./videos\000133.mp4
# Video ./videos\000133 exists. Skipping video creation for this sequence.
# Making video ./videos\000134.mp4
# Video ./videos\000134 exists. Skipping video creation for this sequence.
# Making video ./videos\000135.mp4
# Video ./videos\000135 exists. Skipping video creation for this sequence.
# Making video ./videos\000136.mp4
# Video ./videos\000136 exists. Skipping video creation for this sequence.
# Making video ./videos\000137.mp4
# Video ./videos\000137 exists. Skipping video creation for this sequence.
# Making video ./videos\000138.mp4
# Video ./videos\000138 exists. Skipping video creation for this sequence.
# Making video ./videos\000139.mp4
# Video ./videos\000139 exists. Skipping video creation for this sequence.
# Making video ./videos\000140.mp4
# Video ./videos\000140 exists. Skipping video creation for this sequence.
# Making video ./videos\000141.mp4
# Video ./videos\000141 exists. Skipping video creation for this sequence.
# Making video ./videos\000142.mp4
# Video ./videos\000142 exists. Skipping video creation for this sequence.
# Making video ./videos\000143.mp4
# Video ./videos\000143 exists. Skipping video creation for this sequence.
# Making video ./videos\000144.mp4
# Video ./videos\000144 exists. Skipping video creation for this sequence.
# Making video ./videos\000145.mp4
# Video ./videos\000145 exists. Skipping video creation for this sequence.
# Making video ./videos\000146.mp4
# Video ./videos\000146 exists. Skipping video creation for this sequence.
# Making video ./videos\000147.mp4
# Video ./videos\000147 exists. Skipping video creation for this sequence.
# Making video ./videos\000148.mp4
# Video ./videos\000148 exists. Skipping video creation for this sequence.
# Making video ./videos\000149.mp4
# Video ./videos\000149 exists. Skipping video creation for this sequence.
# Making video ./videos\000150.mp4
# Video ./videos\000150 exists. Skipping video creation for this sequence.
# Making video ./videos\000151.mp4
# Video ./videos\000151 exists. Skipping video creation for this sequence.
# Making video ./videos\000152.mp4
# Video ./videos\000152 exists. Skipping video creation for this sequence.
# Making video ./videos\000153.mp4
# Video ./videos\000153 exists. Skipping video creation for this sequence.
# Making video ./videos\000154.mp4
# Video ./videos\000154 exists. Skipping video creation for this sequence.
# Making video ./videos\000155.mp4
# Video ./videos\000155 exists. Skipping video creation for this sequence.
# Making video ./videos\000156.mp4
# Video ./videos\000156 exists. Skipping video creation for this sequence.
# Making video ./videos\000157.mp4
# Video ./videos\000157 exists. Skipping video creation for this sequence.
# Making video ./videos\000158.mp4
# Video ./videos\000158 exists. Skipping video creation for this sequence.
# Making video ./videos\000159.mp4
# Video ./videos\000159 exists. Skipping video creation for this sequence.
# Making video ./videos\000160.mp4
# Video ./videos\000160 exists. Skipping video creation for this sequence.
# Making video ./videos\000161.mp4
# Video ./videos\000161 exists. Skipping video creation for this sequence.
# Making video ./videos\000162.mp4
# Video ./videos\000162 exists. Skipping video creation for this sequence.
# Making video ./videos\000163.mp4
# Video ./videos\000163 exists. Skipping video creation for this sequence.
# Making video ./videos\000164.mp4
# Video ./videos\000164 exists. Skipping video creation for this sequence.
# Making video ./videos\000165.mp4
# Video ./videos\000165 exists. Skipping video creation for this sequence.
# Making video ./videos\000166.mp4
# Video ./videos\000166 exists. Skipping video creation for this sequence.
# Making video ./videos\000167.mp4
# Video ./videos\000167 exists. Skipping video creation for this sequence.
# Making video ./videos\000168.mp4
# Video ./videos\000168 exists. Skipping video creation for this sequence.
# Making video ./videos\000169.mp4
# Video ./videos\000169 exists. Skipping video creation for this sequence.
# Making video ./videos\000170.mp4
# Video ./videos\000170 exists. Skipping video creation for this sequence.
# Making video ./videos\000171.mp4
# Video ./videos\000171 exists. Skipping video creation for this sequence.
# Making video ./videos\000172.mp4
# Video ./videos\000172 exists. Skipping video creation for this sequence.
# Making video ./videos\000173.mp4
# Video ./videos\000173 exists. Skipping video creation for this sequence.
# Making video ./videos\000174.mp4
# Video ./videos\000174 exists. Skipping video creation for this sequence.
# Making video ./videos\000175.mp4
# Video ./videos\000175 exists. Skipping video creation for this sequence.
# Making video ./videos\000176.mp4
# Video ./videos\000176 exists. Skipping video creation for this sequence.
# Making video ./videos\000177.mp4
# Video ./videos\000177 exists. Skipping video creation for this sequence.
# Making video ./videos\000178.mp4
# Video ./videos\000178 exists. Skipping video creation for this sequence.
# Making video ./videos\000179.mp4
# Video ./videos\000179 exists. Skipping video creation for this sequence.
# Making video ./videos\000180.mp4
# Video ./videos\000180 exists. Skipping video creation for this sequence.
# Making video ./videos\000181.mp4
# Video ./videos\000181 exists. Skipping video creation for this sequence.
# Making video ./videos\000182.mp4
# Video ./videos\000182 exists. Skipping video creation for this sequence.
# Making video ./videos\000183.mp4
# Video ./videos\000183 exists. Skipping video creation for this sequence.
# Making video ./videos\000184.mp4
# Video ./videos\000184 exists. Skipping video creation for this sequence.
# Making video ./videos\000185.mp4
# Video ./videos\000185 exists. Skipping video creation for this sequence.
# Making video ./videos\000186.mp4
# Video ./videos\000186 exists. Skipping video creation for this sequence.
# Making video ./videos\000187.mp4
# Video ./videos\000187 exists. Skipping video creation for this sequence.
# Making video ./videos\000188.mp4
# Video ./videos\000188 exists. Skipping video creation for this sequence.
# Making video ./videos\000189.mp4
# Video ./videos\000189 exists. Skipping video creation for this sequence.
# Making video ./videos\000190.mp4
# Video ./videos\000190 exists. Skipping video creation for this sequence.
# Making video ./videos\000191.mp4
# Video ./videos\000191 exists. Skipping video creation for this sequence.
# Making video ./videos\000192.mp4
# Video ./videos\000192 exists. Skipping video creation for this sequence.
# Making video ./videos\000193.mp4
# Video ./videos\000193 exists. Skipping video creation for this sequence.
# Making video ./videos\000194.mp4
# Video ./videos\000194 exists. Skipping video creation for this sequence.
# Making video ./videos\000195.mp4
# Video ./videos\000195 exists. Skipping video creation for this sequence.
# Making video ./videos\000196.mp4
# Video ./videos\000196 exists. Skipping video creation for this sequence.
# Making video ./videos\000197.mp4
# Video ./videos\000197 exists. Skipping video creation for this sequence.
# Making video ./videos\000198.mp4
# Video ./videos\000198 exists. Skipping video creation for this sequence.
# Making video ./videos\000199.mp4
# Video ./videos\000199 exists. Skipping video creation for this sequence.
# Making video ./videos\000200.mp4
# Video ./videos\000200 exists. Skipping video creation for this sequence.
# Making video ./videos\000201.mp4
# Video ./videos\000201 exists. Skipping video creation for this sequence.
# Making video ./videos\000202.mp4
# Video ./videos\000202 exists. Skipping video creation for this sequence.
# Making video ./videos\000203.mp4
# Video ./videos\000203 exists. Skipping video creation for this sequence.
# Making video ./videos\000204.mp4
# Video ./videos\000204 exists. Skipping video creation for this sequence.

# %%
#Gemini API Key setup
with open(".env") as f:
    gemini_api_key = f.read().strip().split('=')[1]

#Load the Gemini API key
client = genai.Client(api_key=gemini_api_key)

# %%
def get_gemini_response(prompt: str, video_path: str) -> str:
    """
    Sends a prompt and a video file to Gemini 2.5 and returns the response.

    Args:
        prompt (str): The prompt to send.
        video_path (str): Path to the video file.

    Returns:
        str: Gemini's response.
    """
    #Give me the size of the video in MB -- if bigger than 20 MB, print a warning
    video_size = os.path.getsize(video_path) / (1024 * 1024)  # Convert to MB
    if video_size > 20:
        print(f"Warning: Video size is {video_size:.2f} MB, which is larger than the recommended 20 MB.")
        return ""
    video_bytes = open(video_path, 'rb').read()

    response = client.models.generate_content(
        model='models/gemini-2.0-flash',
        contents=types.Content(
            parts=[
                types.Part(
                    inline_data=types.Blob(data=video_bytes, mime_type='video/mp4')
                ),
                types.Part(text=prompt)
            ]
        )
    )
    return response.text

# %%
responses = {}

for video_file in os.listdir(video_folder):
    if video_file.endswith('.mp4'):
        video_path = os.path.join(video_folder, video_file)
        response = get_gemini_response(message, video_path)
        print(f"Response for {video_file}:")
        print(response)
        responses[video_file] = response


# Save responses to a json file
with open(output_file, 'w') as f:
    for response in responses:
        f.write(json.dumps(response) + '\n')
# Out:
# Response for 000000.mp4:
# Okay, I will analyze the provided frames and give you the information based on your instructions.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: Angle/Side Impact
# 3.  Person Injury: Yes
# 4.  Need for ambulance: Yes (due to visible injuries)
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes (standard for traffic accidents with injuries)
# 7.  Types of vehicles involved: Motorcycle/Scooter and Motorcycle/Scooter
# 8.  Fire: No
# 9.  Day/night and weather: Day, clear
# 10. Low Res/Bad Footage: Yes
#
# Response for 000001.mp4:
# Okay, here's a breakdown of the potential traffic incident based on the provided frames:
#
# 1.  **Number of vehicles in accident:** 4
#
# 2.  **Accident Type:**  Multiple rear-end collisions and possibly some glancing blows. It is a chain reaction.
#
# 3.  **Person Injury:** Unable to assess from the images.  Potentially yes.
#
# 4.  **Need for ambulance:** Unable to assess from the images. Potentially yes.
#
# 5.  **Need for firetruck:** Unable to assess from the images. Potentially no.
#
# 6.  **Need for Police:**  Likely yes, due to multiple vehicles involved and potential injuries.
#
# 7.  **Types of vehicles involved:** Appears to be mostly sedans and SUVs.
#
# 8.  **Fire:** No
#
# 9.  **Day/night and weather:** Day, snowy conditions.
#
# 10. **Low Res/Bad Footage:**  Yes, the footage is low resolution.
#
# Response for 000002.mp4:
# Okay, I will analyze the provided frames to provide the requested information. Keep in mind this is demo only and not real.
#
# 1.  **Number of vehicles in accident:** 4
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Yes (Likely, based on the severity of the impact)
# 4.  **Need for ambulance:** Yes (Likely, given the potential for injuries)
# 5.  **Need for firetruck:** Yes (Because there is a fire)
# 6.  **Need for Police:** Yes (Standard for accidents, especially with injuries)
# 7.  **Types of vehicles involved:** 2 SUVs, 2 Trucks, 1 sedan
# 8.  **Fire:** Yes
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000003.mp4:
# Okay, I will analyze the frames you provided based on your instructions.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Yes (due to the severity of the impact)
# 4.  Need for ambulance: Yes
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Sedan, Light Van
# 8.  Fire: No
# 9.  Day/night and weather: Day, clear
# 10. Low Res/Bad Footage: No
#
# Response for 000004.mp4:
# Okay, here's an analysis of the provided frames based on your request:
#
# 1.  **Number of vehicles in accident:** 1
# 2.  **Accident Type:** Unknown
# 3.  **Person Injury:** Unknown
# 4.  **Need for ambulance:** Unknown
# 5.  **Need for firetruck:** Unknown
# 6.  **Need for Police:** Unknown
# 7.  **Types of vehicles involved:** Truck
# 8.  **Fire:** no
# 9.  **Day/night and weather:** Night, unknown weather
# 10. **Low Res/Bad Footage:** yes
# Response for 000005.mp4:
# Okay, I will analyze the provided frames to the best of my ability given the video quality. Here's my assessment:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone. One vehicle appears to be struck on the side.
# 3.  **Person Injury:** Difficult to determine from the footage, but given the severity of the impact, it's possible. My best guess is yes.
# 4.  **Need for ambulance:** Likely, due to the nature of the accident. My best guess is yes.
# 5.  **Need for firetruck:** Difficult to say with certainty. There does not appear to be fire. My best guess is no.
# 6.  **Need for Police:** Almost certainly, to investigate and file a report. My best guess is yes.
# 7.  **Types of vehicles involved:** Appears to be an SUV and it is difficult to ascertain the other vehicle.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Night and the weather appears to be clear.
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000006.mp4:
# Okay, I will analyze the frames and provide the requested information.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone (likely, given the visible movement and impact)
# 3.  **Person Injury:** Cannot determine from the image.
# 4.  **Need for ambulance:** Cannot determine from the image.
# 5.  **Need for firetruck:** Cannot determine from the image.
# 6.  **Need for Police:** Likely, given that it is a car accident.
# 7.  **Types of vehicles involved:** Based on the images, it's hard to determine but they appear to be sedan type vehicles.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Night, weather is likely clear.
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000007.mp4:
# Okay, I will analyze the video frames based solely on the visual information provided and answer your questions.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Cannot determine with certainty from the provided frames.
# 4.  Need for ambulance: Cannot determine with certainty from the provided frames.
# 5.  Need for firetruck: No
# 6.  Need for Police: Cannot determine with certainty from the provided frames, but likely needed due to accident type.
# 7.  Types of vehicles involved: Sedan, undetermined second vehicle
# 8.  Fire: No
# 9.  Day/night and weather: Night, weather appears clear.
# 10. Low Res/Bad Footage: Yes
#
# Response for 000008.mp4:
# Okay, I will analyze the video based on the information provided and give you the best possible answers given the quality.
#
# 1.  **Number of vehicles in accident:** 0
# 2.  **Accident Type:** None
# 3.  **Person Injury:** No
# 4.  **Need for ambulance:** No
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** No
# 7.  **Types of vehicles involved:** Sedan
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, weather unknown but appears clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000009.mp4:
# Okay, I will analyze the provided frames and give you the requested information based solely on what I can observe:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Appears to be a side-impact collision (T-bone).
# 3.  **Person Injury:** Unable to determine from the image.
# 4.  **Need for ambulance:** Unable to determine from the image.
# 5.  **Need for firetruck:** Unable to determine from the image.
# 6.  **Need for Police:** Unable to determine from the image.
# 7.  **Types of vehicles involved:** SUV and Pickup Truck.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Night; weather conditions are not discernible.
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000010.mp4:
# Okay, I will analyze the provided frames and provide quantitative information as requested, keeping in mind this is a demo and the footage quality is likely low.
#
# 1.  **Number of vehicles in accident:** 3
# 2.  **Accident Type:** Based on the video, this appears to be a chain-reaction type accident or a multiple rear-end collision.
# 3.  **Person Injury:** Due to the low resolution, I cannot definitively say. I will say likely yes due to the impact severity, but cannot confirm.
# 4.  **Need for ambulance:** Likely yes, given the severity of the collision.
# 5.  **Need for firetruck:** Possibly, but not definite. Primarily needed if there's a fire or extensive vehicle damage requiring extraction, which I cannot confirm in this video.
# 6.  **Need for Police:** Yes, to investigate the accident, manage traffic, and file a report.
# 7.  **Types of vehicles involved:** Multiple sedans and/or SUVs. Hard to discern exact models due to the resolution.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Daytime, clear weather.
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000011.mp4:
# Okay, I will do my best to provide the requested information based on the images provided. Keep in mind the quality is low and this is a simulated scenario.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-Bone
# 3.  Person Injury: Maybe (Difficult to determine)
# 4.  Need for ambulance: Maybe (Difficult to determine)
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Sedan, Taxi (Looks like a Taxi)
# 8.  Fire: No
# 9.  Day/night and weather: Day, weather unclear
# 10. Low Res/Bad Footage: Yes
#
# Response for 000012.mp4:
# Okay, I will analyze the images and provide the information based solely on what I can observe in the frames.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Unknown
# 4.  **Need for ambulance:** Unknown
# 5.  **Need for firetruck:** Unknown
# 6.  **Need for Police:** Unknown
# 7.  **Types of vehicles involved:** Sedan, undetermined
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, rainy (visibility low)
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000013.mp4:
# Okay, here's an analysis of the frames, based solely on the visual information provided:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Rear end.
# 3.  **Person Injury:** Cannot determine from this footage.
# 4.  **Need for ambulance:** Cannot determine from this footage.
# 5.  **Need for firetruck:** No.
# 6.  **Need for Police:** Likely.
# 7.  **Types of vehicles involved:** 2 Sedans.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Night, weather conditions not determinable.
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000014.mp4:
# Okay, I will analyze the provided frames and provide the requested information based on my observations. Please remember that due to the low resolution and potentially incomplete information in the images, my analysis is an estimation and may not be entirely accurate.
#
# Here's the breakdown:
#
# 1.  **Number of vehicles in accident:** 3
# 2.  **Accident Type:** T-Bone/Side Impact.  It appears one vehicle may have impacted another at a near perpendicular angle.
# 3.  **Person Injury:**  Potentially yes. The severity of the impact suggests there is a risk of injury.
# 4.  **Need for ambulance:** Likely yes.
# 5.  **Need for firetruck:** Possibly yes. Depending on damage to vehicles and the need for extrication.
# 6.  **Need for Police:** Yes.  Traffic accidents of this nature generally require police intervention for documentation, investigation, and traffic control.
# 7.  **Types of vehicles involved:** Sedans are primarily visible, possibly an SUV is present.
# 8.  **Fire:** No (no signs of fire are visible)
# 9.  **Day/night and weather:**  Daytime, possibly wet conditions (the road appears wet/reflective).
# 10. **Low Res/Bad Footage:** Yes. The footage is low resolution and grainy.
#
# Response for 000015.mp4:
# Okay, I will analyze the frames and provide quantitative information as requested.
#
# 1.  **Number of vehicles in accident:** Based on the single frame provided, it is unclear if there is an accident. I see several vehicles moving in an intersection. Thus, the number cannot be determined.
#
# 2.  **Accident Type:** Not determinable from the image.
#
# 3.  **Person Injury:** Not determinable from the image.
#
# 4.  **Need for ambulance:** Not determinable from the image.
#
# 5.  **Need for firetruck:** Not determinable from the image.
#
# 6.  **Need for Police:** Possibly yes, since the footage is from Dubai Police.
#
# 7.  **Types of vehicles involved:** Sedan, truck, and possibly other vehicle types.
#
# 8.  **Fire:** No.
#
# 9.  **Day/night and weather:** Night, possibly wet due to reflections on the road.
#
# 10. **Low Res/Bad Footage:** Low resolution.
#
# Response for 000016.mp4:
# Okay, I will analyze the provided frames to the best of my ability, focusing on potential traffic incidents based on the information given.
#
# 1.  **Number of vehicles in accident:** I cannot see an accident.
# 2.  **Accident Type:** Cannot determine as no accident is visible.
# 3.  **Person Injury:** Cannot determine.
# 4.  **Need for ambulance:** Cannot determine.
# 5.  **Need for firetruck:** Cannot determine.
# 6.  **Need for Police:** Cannot determine.
# 7.  **Types of vehicles involved:**  Bus, sedan
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Day, clear.
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000017.mp4:
# Okay, I will analyze the images based solely on what I can see and provide the requested information to the best of my ability, keeping in mind it's a demo and the footage may be limited.
#
# 1.  **Number of vehicles in accident:** 0 (Based on the provided frames, there is no visible accident.)
#
# 2.  **Accident Type:** N/A (No accident is visible)
#
# 3.  **Person Injury:** No (No visible evidence of injury)
#
# 4.  **Need for ambulance:** No (No indication of need)
#
# 5.  **Need for firetruck:** No (No fire or immediate hazard)
#
# 6.  **Need for Police:** No (No accident or crime in view)
#
# 7.  **Types of vehicles involved:** SUVs, sedans, van, motorcycle/scooter
#
# 8.  **Fire:** No
#
# 9.  **Day/night and weather:** Day, clear
#
# 10. **Low Res/Bad Footage:** No (The footage appears to be of moderate quality)
# Response for 000018.mp4:
# Okay, I will analyze the video frames and provide the requested information.
#
# 1.  **Number of vehicles in accident:** Cannot be determined from this image. The image shows an empty intersection.
# 2.  **Accident Type:** Cannot be determined from this image.
# 3.  **Person Injury:** Cannot be determined from this image.
# 4.  **Need for ambulance:** Cannot be determined from this image.
# 5.  **Need for firetruck:** Cannot be determined from this image.
# 6.  **Need for Police:** Cannot be determined from this image.
# 7.  **Types of vehicles involved:** Cannot be determined from this image.
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, clear
# 10. **Low Res/Bad Footage:** Yes
#
# **Note:** This analysis is based solely on the provided frames. Without additional context or video, the assessment is limited.
#
# Response for 000019.mp4:
# Okay, I will analyze the provided frames and give you the requested information to the best of my ability.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Appears to be a T-bone or angle collision.
# 3.  **Person Injury:** Potentially yes (based on the nature of the collision), but not definitively visible in the image.
# 4.  **Need for ambulance:** Potentially yes.
# 5.  **Need for firetruck:** No.
# 6.  **Need for Police:** Yes.
# 7.  **Types of vehicles involved:** SUV and Sedan.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Night, appears to be wet conditions.
# 10. **Low Res/Bad Footage:** Yes.
# Response for 000020.mp4:
# Okay, I will analyze the image and provide the information you requested, focusing solely on the visual data present in the frame.
#
# 1.  **Number of vehicles in accident:** 0
#
# 2.  **Accident Type:** None
#
# 3.  **Person Injury:** No
#
# 4.  **Need for ambulance:** No
#
# 5.  **Need for firetruck:** No
#
# 6.  **Need for Police:** No
#
# 7.  **Types of vehicles involved:** sedans, SUVs, taxis
#
# 8.  **Fire:** No
#
# 9.  **Day/night and weather:** Day, clear
#
# 10. **Low Res/Bad Footage:** No
#
# Response for 000021.mp4:
# Okay, I will analyze the provided frames and provide the requested information to the best of my ability.
#
# Here's my analysis based on the video:
#
# 1.  **Number of vehicles in accident:** 0. The video does not show an accident. The video shows cars traveling normally.
#
# 2.  **Accident Type:** N/A
#
# 3.  **Person Injury:** No.
#
# 4.  **Need for ambulance:** No.
#
# 5.  **Need for firetruck:** No.
#
# 6.  **Need for Police:** No.
#
# 7.  **Types of vehicles involved:** The video shows multiple cars which include sedans and SUVs.
#
# 8.  **Fire:** No.
#
# 9.  **Day/night and weather:** Night, wet.
#
# 10. **Low Res/Bad Footage:** Yes, the footage is low resolution and blurry.
#
# Response for 000022.mp4:
# Okay, I'll analyze the frames provided based on your instructions.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Undetermined
# 4.  **Need for ambulance:** Possible
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Sedan, sports car (or coupe)
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000023.mp4:
# Okay, I will analyze the provided frames and provide the requested information to the best of my ability, keeping in mind the "demo only" disclaimer.
#
# 1.  **Number of vehicles in accident:** 2 (Based on the movement leading up to a potential collision)
# 2.  **Accident Type:** Potential T-bone. The SUV appears to be crossing the path of the truck, suggesting a potential side impact.
# 3.  **Person Injury:** Unknown. With the given information it is not possible to know if anyone was injured.
# 4.  **Need for ambulance:** Unknown
# 5.  **Need for firetruck:** No. There is no indication of fire or hazardous materials.
# 6.  **Need for Police:** Likely. Given the nature of a collision, police presence for investigation and documentation would be standard.
# 7.  **Types of vehicles involved:** Truck, SUV
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, clear
# 10. **Low Res/Bad Footage:** Yes, low resolution.
#
# **Important Considerations:**
#
# *   **Demo Only:** This analysis is based solely on visual information from the provided frames, which are explicitly stated as "demo only" and "not real."
# *   **Limited Information:** The accuracy of my analysis is limited by the quality of the video, the limited view of the scene, and the absence of contextual information.
#
#
# Response for 000024.mp4:
# Okay, I will analyze the provided frames based on your instructions. Please remember that this is a single frame analysis, and I'm doing my best with limited information.
#
# Here's my assessment:
#
# 1.  Number of vehicles in accident: **0**
# 2.  Accident Type: **None**
# 3.  Person Injury: **No**
# 4.  Need for ambulance: **No**
# 5.  Need for firetruck: **No**
# 6.  Need for Police: **No**
# 7.  Types of vehicles involved: **Sedans, SUVs, Buses, Trucks**
# 8.  Fire: **No**
# 9.  Day/night and weather: **Day, Clear**
# 10. Low Res/Bad Footage: **Yes**
#
# **Disclaimer:** *My analysis is based solely on the visual information provided in the still images. It is limited and may not be entirely accurate. A real investigation would require more data.*
#
# Response for 000025.mp4:
# Okay, here's my analysis of the traffic incident based on the provided frames, keeping in mind this is demo footage:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Cannot determine from this footage.
# 4.  **Need for ambulance:** Cannot determine from this footage.
# 5.  **Need for firetruck:** Cannot determine from this footage.
# 6.  **Need for Police:** Likely, due to the nature of the accident.
# 7.  **Types of vehicles involved:** Sedan and SUV
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Day, clear weather.
# 10. **Low Res/Bad Footage:** No
#
# Response for 000026.mp4:
# Okay, I will analyze the images based on your request:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Trailer separation, leading to trailer crash
# 3.  **Person Injury:** Yes
# 4.  **Need for ambulance:** Yes
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Van and trailer
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000027.mp4:
# Okay, I will do my best to provide the requested information based solely on the image provided. Please remember that with low-resolution footage, my assessment may be limited and could be inaccurate.
#
# Here's my analysis:
#
# 1.  **Number of vehicles in accident:** 2
#
# 2.  **Accident Type:** Rear end (most probable based on limited view)
#
# 3.  **Person Injury:** Unknown
#
# 4.  **Need for ambulance:** Possibly (presence of emergency vehicles suggests it)
#
# 5.  **Need for firetruck:** Possibly (presence of emergency vehicles suggests it)
#
# 6.  **Need for Police:** Yes (presence of emergency vehicles suggests it)
#
# 7.  **Types of vehicles involved:**
#     *   Appears to be at least one Sedan
#     *   Other vehicles appear to be Sedan.
#
# 8.  **Fire:** No
#
# 9.  **Day/night and weather:** Day, Rain
#
# 10. **Low Res/Bad Footage:** Yes
# Response for 000028.mp4:
# Okay, I will analyze the provided frames and provide the requested information to the best of my ability. Please remember that this analysis is based on limited visual information and is for demo purposes only.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-Bone
# 3.  **Person Injury:** Possibly - hard to determine from the images
# 4.  **Need for ambulance:** Possibly - hard to determine from the images
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Sedan, Truck
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Clear
# 10. **Low Res/Bad Footage:** No
#
# Response for 000029.mp4:
# Okay, I will analyze the video frames and provide the requested information. Here's the breakdown:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Likely yes (based on the severity of the impact).
# 4.  **Need for ambulance:** Likely yes (due to the T-bone collision and potential injuries).
# 5.  **Need for firetruck:** Unknown but unlikely (unless there is a fuel leak or fire risk).
# 6.  **Need for Police:** Yes (to investigate the accident and determine fault).
# 7.  **Types of vehicles involved:** Truck, Sedan
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Clear weather
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000030.mp4:
# Okay, I will analyze the provided frames to the best of my ability and provide the requested information. Please note that due to the low resolution and poor quality of the video, some estimations might be less accurate.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Likely yes (given the severity of the impact)
# 4.  **Need for ambulance:** Yes (due to the likely injuries)
# 5.  **Need for firetruck:** Possibly (depending on if there is any potential for fire or need for vehicle extrication)
# 6.  **Need for Police:** Yes (accident of this nature will need a police investigation)
# 7.  **Types of vehicles involved:** Truck, sedan
# 8.  **Fire:** No (no flames are visible in the provided frames)
# 9.  **Day/night and weather:** Night, likely wet (based on the road appearance and lighting)
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000031.mp4:
# Okay, here's a breakdown of the potential traffic incident based on the frames, keeping in mind the disclaimer about the footage being demo only and not real:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** The accident type appears to be a rollover.
# 3.  **Person Injury:** Based on the video, it's difficult to determine if there are injuries. So, the answer is no.
# 4.  **Need for ambulance:** Unknown; it's impossible to determine from the visual alone. So, the answer is no.
# 5.  **Need for firetruck:** Based on the video, there are no indication to need a fire truck so the answer is no.
# 6.  **Need for Police:** Potentially yes, due to the nature of the accident (rollover).
# 7.  **Types of vehicles involved:** Truck and possibly car.
# 8.  **Fire:** No, no fire is visible.
# 9.  **Day/night and weather:** Day, and it appears to be clear.
# 10. **Low Res/Bad Footage:** Yes, the footage is low resolution and has timestamping that obstructs visibility.
# Response for 000032.mp4:
# Okay, I will analyze the provided frames to the best of my ability, keeping in mind the limitations of the low resolution and bad footage. Here's the breakdown:
#
# 1.  **Number of vehicles in accident:** Unable to determine from this frame.
#
# 2.  **Accident Type:** Unable to determine from this frame.
#
# 3.  **Person Injury:** Unable to determine from this frame.
#
# 4.  **Need for ambulance:** Unable to determine from this frame.
#
# 5.  **Need for firetruck:** Unable to determine from this frame.
#
# 6.  **Need for Police:** Unable to determine from this frame.
#
# 7.  **Types of vehicles involved:** Appears to be at least one sedan-type vehicle.
#
# 8.  **Fire:** No.
#
# 9.  **Day/night and weather:** Daytime, weather is unclear but appears to be clear.
#
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000033.mp4:
# Okay, I will analyze the video frames you provided to identify potential traffic incident details.
#
# 1.  Number of vehicles in the accident: 2
# 2.  Accident Type: Head-on collision
# 3.  Person Injury: Yes, high probability due to the nature of the impact.
# 4.  Need for ambulance: Yes
# 5.  Need for firetruck: Possible, depending on the extent of damage and potential hazards (fuel leaks).
# 6.  Need for Police: Yes, to investigate the accident and manage traffic.
# 7.  Types of vehicles involved: Truck and sedan
# 8.  Fire: No
# 9.  Day/night and weather: Day and clear
# 10. Low Res/Bad Footage: Yes
#
# Response for 000034.mp4:
# Okay, I will analyze the frames to the best of my ability and provide quantitative information when possible:
#
# 1.  **Number of vehicles in accident:** Difficult to determine with certainty from the footage, but it *appears* to be 1.
#
# 2.  **Accident Type:** The vehicle appears to be swerving or out of control rather than involved in a collision.
#
# 3.  **Person Injury:** Unknown. No clear evidence.
#
# 4.  **Need for ambulance:** Unknown.
#
# 5.  **Need for firetruck:** No.
#
# 6.  **Need for Police:** Possibly, given the potential for a traffic violation or uncontrolled vehicle.
#
# 7.  **Types of vehicles involved:** One SUV visible.
#
# 8.  **Fire:** No.
#
# 9.  **Day/night and weather:** Night, and the road appears wet and rainy.
#
# 10. **Low Res/Bad Footage:** Yes. The footage is low resolution and blurry, making details difficult to discern.
# Response for 000035.mp4:
# Okay, I will analyze the image to the best of my ability based on the information provided.
#
# 1.  **Number of vehicles in accident:** 2
#
# 2.  **Accident Type:** T-bone
#
# 3.  **Person Injury:** Unknown
#
# 4.  **Need for ambulance:** Unknown
#
# 5.  **Need for firetruck:** No
#
# 6.  **Need for Police:** Unknown
#
# 7.  **Types of vehicles involved:** Truck, Sedan
#
# 8.  **Fire:** No
#
# 9.  **Day/night and weather:** Day, Snowy
#
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000036.mp4:
# Here's an analysis of the provided video frames, focusing on the traffic incident:
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Yes (Likely, given the severity of the impact to the motorcyclist)
# 4.  Need for ambulance: Yes
# 5.  Need for firetruck: Unlikely
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Truck, Motorcycle
# 8.  Fire: No
# 9.  Day/night and weather: Day, clear
# 10. Low Res/Bad Footage: Yes
#
# Response for 000037.mp4:
# Okay, I will do my best to analyze the frames provided based solely on the visual information and ignoring any prior context.
#
# 1.  **Number of vehicles in accident:** 1
#
# 2.  **Accident Type:** Rollover/Loss of Control (based on the vehicle's position and lack of another visible vehicle)
#
# 3.  **Person Injury:** Unknown (based on visual evidence alone)
#
# 4.  **Need for ambulance:** Unknown (based on visual evidence alone)
#
# 5.  **Need for firetruck:** Unknown (based on visual evidence alone)
#
# 6.  **Need for Police:** Unknown (based on visual evidence alone)
#
# 7.  **Types of vehicles involved:** Appears to be a SUV or van type vehicle.
#
# 8.  **Fire:** No
#
# 9.  **Day/night and weather:** Day, Weather appears clear
#
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000038.mp4:
# Okay, I will analyze the frames and provide the requested information.
#
# 1.  **Number of vehicles in accident:** 5
# 2.  **Accident Type:** Chain reaction / Pile-up
# 3.  **Person Injury:** Likely yes (due to the severity of the collision)
# 4.  **Need for ambulance:** Yes
# 5.  **Need for firetruck:** Possibly (to assess safety, but no visible fire)
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Van, Truck, Sedan, Bus
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000039.mp4:
# Okay, here's the analysis based on the provided frames, keeping in mind this is a demo/simulation:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Possible T-bone or side impact (hard to determine exact angle)
# 3.  **Person Injury:** Cannot determine definitively, likely possible
# 4.  **Need for ambulance:** Likely Yes
# 5.  **Need for firetruck:** Unlikely
# 6.  **Need for Police:** Likely Yes
# 7.  **Types of vehicles involved:** Van/Small Truck and Truck
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Rainy/Wet
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000040.mp4:
# Okay, here's an analysis based solely on the provided frames, keeping in mind this is a demonstration:
#
# 1.  **Number of vehicles in accident:** 1
#
# 2.  **Accident Type:** Single vehicle accident, possibly collision with a fixed object.
#
# 3.  **Person Injury:** Unable to determine from image.
#
# 4.  **Need for ambulance:** Unable to determine from image. Likely needed.
#
# 5.  **Need for firetruck:** Unable to determine from image.
#
# 6.  **Need for Police:** Likely, due to the nature of the accident and potential road obstruction.
#
# 7.  **Types of vehicles involved:** Truck or SUV.
#
# 8.  **Fire:** No.
#
# 9.  **Day/night and weather:** Daytime, weather is clear.
#
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000041.mp4:
# Okay, I will do my best to analyze the provided frames and give you the requested information. Please remember this is a limited analysis based on a short video clip.
#
# 1.  **Number of vehicles in accident:** 1
# 2.  **Accident Type:** Single Vehicle Loss of Control
# 3.  **Person Injury:** Likely yes. (Due to the severity of the crash.)
# 4.  **Need for ambulance:** Likely yes.
# 5.  **Need for firetruck:** Potentially yes. (Depends on the presence of fire or need for extraction.)
# 6.  **Need for Police:** Yes. (Accidents involving potential injury and property damage always require police investigation.)
# 7.  **Types of vehicles involved:** Sedan.
# 8.  **Fire:** No, but smoke is present.
# 9.  **Day/night and weather:** Night, wet.
# 10. **Low Res/Bad Footage:** Yes.
#
# **Disclaimer:** This analysis is based solely on the visual information in the provided frames. A real-world investigation would require much more information.
#
# Response for 000042.mp4:
# Here's an analysis of the traffic incident based on the provided frames:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-Bone
# 3.  **Person Injury:** Likely yes (due to the severity of the impact)
# 4.  **Need for ambulance:** Likely yes
# 5.  **Need for firetruck:** Possibly, but not confirmed from the image
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Sedans
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** Yes
#
# **Important Note:** This analysis is based solely on the provided frames and assumes a standard interpretation of traffic incidents. The actual situation may differ, and professional investigation is necessary for accurate conclusions.
#
# Response for 000043.mp4:
# Okay, I will analyze the provided frames to the best of my ability, keeping in mind that the footage is low resolution and may not provide a complete picture.
#
# Here's my assessment:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Side swipe
# 3.  **Person Injury:** Unknown, but potentially yes due to the severity of impact.
# 4.  **Need for ambulance:** Possibly yes, depending on injuries sustained.
# 5.  **Need for firetruck:** No, there is no visual indication of fire.
# 6.  **Need for Police:** Yes, an accident with this level of damage typically requires a police report.
# 7.  **Types of vehicles involved:** Car (sedan) and Bus.
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Clear.
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000044.mp4:
# Okay, I will analyze the provided frames and provide quantitative information based on them. Please remember this is demo only, and the accuracy is limited by the quality of the footage.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Appears to be a collision between a truck/pickup and a motorcycle, possibly a side impact or the motorcycle clipping the truck as the truck was merging into traffic.
# 3.  **Person Injury:** Likely yes (motorcyclist involved)
# 4.  **Need for ambulance:** Likely yes.
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Truck/Pickup, Motorcycle
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000045.mp4:
# Okay, here is an analysis based on the provided frames, focusing solely on what can be observed from the video, without making any assumptions about previous context:
#
# 1.  Number of vehicles in accident: 1
# 2.  Accident Type: Motorcycle vs Person
# 3.  Person Injury: Yes
# 4.  Need for ambulance: Likely yes
# 5.  Need for firetruck: No
# 6.  Need for Police: Likely yes
# 7.  Types of vehicles involved: Motorcycle and Person
# 8.  Fire: No
# 9.  Day/night and weather: Day, Clear
# 10. Low Res/Bad Footage: Yes
#
# Response for 000046.mp4:
# Okay, I will analyze the provided frames and provide quantitative information based on my observations.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Yes (likely, based on the impact and the person falling)
# 4.  Need for ambulance: Yes (likely, based on the potential for injuries)
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes (due to the accident and potential injuries)
# 7.  Types of vehicles involved: Sedan, Scooter/Motorcycle
# 8.  Fire: No
# 9.  Day/night and weather: Day, Clear
# 10. Low Res/Bad Footage: Yes
# Response for 000047.mp4:
# Okay, I will analyze the provided frames and give you the requested information.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Unknown
# 4.  **Need for ambulance:** Likely
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** SUV and Sedan (or similar)
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Clear
# 10. **Low Res/Bad Footage:** No
#
# Response for 000048.mp4:
# Okay, I will analyze the image based on your instructions and provide the quantitative information and answers to your questions.
#
# Here's the analysis:
#
# 1.  **Number of vehicles in accident:** 2 (based on the visible interaction and potential damage)
# 2.  **Accident Type:** T-bone (inferred from the positioning of the vehicles in the intersection)
# 3.  **Person Injury:**  Cannot determine definitively from the image.
# 4.  **Need for ambulance:** Cannot determine definitively from the image.
# 5.  **Need for firetruck:**  Cannot determine definitively from the image.
# 6.  **Need for Police:** Likely yes (due to the nature of the accident and potential for injuries or property damage)
# 7.  **Types of vehicles involved:** Pickup truck, Sedans (multiple)
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Clear
# 10. **Low Res/Bad Footage:** Yes (image quality is not ideal for detailed analysis)
#
# **Important Note:** This analysis is based solely on the provided image and is limited by the image quality and lack of additional information. A more accurate assessment would require higher resolution footage, multiple perspectives, and details from the scene.
#
# Response for 000049.mp4:
# Okay, here's an analysis of the provided frames, focusing on quantitative information and the specific points you requested:
#
# 1.  **Number of vehicles in accident:** 1
# 2.  **Accident Type:** Pedestrian Struck
# 3.  **Person Injury:** Yes
# 4.  **Need for ambulance:** Yes
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Sedan, Motorcycle, SUV
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day/clear
# 10. **Low Res/Bad Footage:** Yes
# Response for 000050.mp4:
# Okay, I will analyze the frames based on your instructions.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Possible
# 4.  Need for ambulance: Possible
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: SUV and sedan
# 8.  Fire: No
# 9.  Day/night and weather: Day, overcast
# 10. Low Res/Bad Footage: Yes
#
# Response for 000051.mp4:
# Okay, I'll analyze the images to the best of my ability.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Yes
# 4.  Need for ambulance: Yes
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Sedan, Scooter
# 8.  Fire: No
# 9.  Day/night and weather: Day, Clear
# 10. Low Res/Bad Footage: Yes
# Response for 000052.mp4:
# Okay, here's the analysis of the traffic incident based on the provided frames:
#
# 1.  Number of vehicles in accident: 2
#
# 2.  Accident Type: T-bone
#
# 3.  Person Injury: Yes (Based on the person lying in the crosswalk after the impact.)
#
# 4.  Need for ambulance: Yes (Likely, given the person is lying in the road after impact, suggesting potential injury.)
#
# 5.  Need for firetruck: No (No visible fire or indication of hazardous materials.)
#
# 6.  Need for Police: Yes (Given the accident and potential for injuries, police involvement is likely.)
#
# 7.  Types of vehicles involved: Sedan and Sedan
#
# 8.  Fire: No
#
# 9.  Day/night and weather: Day, unclear weather conditions (likely overcast due to image quality).
#
# 10. Low Res/Bad Footage: Yes
#
# Response for 000053.mp4:
# Okay, I will do my best to analyze the provided images and provide quantitative information as requested, keeping in mind the limitations of the footage quality.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone (based on the initial images, a vehicle appears to collide with the side of another)
# 3.  **Person Injury:** Likely yes (given the type of accident and vehicles involved, injuries are probable)
# 4.  **Need for ambulance:** Likely yes (due to the potential for injuries)
# 5.  **Need for firetruck:** Likely no (no visible signs of fire or hazardous materials)
# 6.  **Need for Police:** Yes (accident involving large vehicles and likely injuries requires police investigation and traffic control)
# 7.  **Types of vehicles involved:** Truck, cement mixer
# 8.  **Fire:** No (no visible fire)
# 9.  **Day/night and weather:** Day, rainy (wet road surface and visible rain)
# 10. **Low Res/Bad Footage:** Yes (footage is low resolution and blurry, making precise assessment difficult)
#
# Response for 000054.mp4:
# Okay, I will analyze the video frames to provide the requested information. Please remember that due to the low resolution and limited visibility, the accuracy of some answers may be affected.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Likely yes (due to the severity of the impact)
# 4.  **Need for ambulance:** Yes
# 5.  **Need for firetruck:** Possibly yes (due to severity of the impact and the presence of a firetruck, it may be responding to this)
# 6.  **Need for Police:** Yes (for accident investigation)
# 7.  **Types of vehicles involved:** Sedan, Van
# 8.  **Fire:** No (no visible flames)
# 9.  **Day/night and weather:** Day, Rainy
# 10. **Low Res/Bad Footage:** Yes
# Response for 000055.mp4:
# Okay, I will analyze the provided frames to provide the requested information.
#
# 1.  **Number of vehicles in accident:** 0 (There is no accident, the cars are all moving independently. )
# 2.  **Accident Type:** N/A
# 3.  **Person Injury:** no
# 4.  **Need for ambulance:** no
# 5.  **Need for firetruck:** no
# 6.  **Need for Police:** no
# 7.  **Types of vehicles involved:** Cars (sedans, vans, taxi, bus)
# 8.  **Fire:** no
# 9.  **Day/night and weather:** Day, appears to be clear
# 10. **Low Res/Bad Footage:** no
#
# Response for 000056.mp4:
# Okay, I will analyze the video frames to identify the requested information:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Likely yes (Person is seen on ground)
# 4.  **Need for ambulance:** Likely yes
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Van, Motorcycle
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000057.mp4:
# Okay, I will analyze the video based on the information you provided:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Likely yes (given the severity of a T-bone collision)
# 4.  **Need for ambulance:** Likely yes (given the potential for injuries)
# 5.  **Need for firetruck:** Unlikely (no visible fire or immediate need for extraction tools based on the video frame)
# 6.  **Need for Police:** Yes (accident investigation, traffic control)
# 7.  **Types of vehicles involved:** Sedan and SUV
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, possible wet conditions (based on the reflective road surface)
# 10. **Low Res/Bad Footage:** Yes (poor image quality makes definitive assessment challenging)
#
# Response for 000058.mp4:
# Okay, I'll analyze the frames based solely on the visual information provided and without prior context.
#
# 1.  **Number of vehicles in accident:** 0 (Based on these frames, there's no visible collision.)
# 2.  **Accident Type:** None (No accident visible)
# 3.  **Person Injury:** Unknown (No visible injuries in these frames)
# 4.  **Need for ambulance:** Unknown (Cannot determine from these frames)
# 5.  **Need for firetruck:** No (No fire visible)
# 6.  **Need for Police:** Unknown (Cannot determine from these frames)
# 7.  **Types of vehicles involved:**  Sedan, Motorcycle or Scooter (One vehicle appearing to be a sedan is visible. Another vehicle appears to be a motorcycle or scooter)
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, Weather appears to be wet based on how the car lights are reflecting on the road.
# 10. **Low Res/Bad Footage:** Yes (The footage is of low resolution.)
#
# Response for 000059.mp4:
# Okay, here is an analysis of the provided frames, keeping in mind it's a demo and the footage is potentially low resolution:
#
# 1.  **Number of vehicles in accident:** Undetermined, I'm unable to detect if the vehicles are involved in an accident,
# 2.  **Accident Type:** Undetermined. I can't determine if there is a collision.
# 3.  **Person Injury:** Unknown. I cannot determine if there is an accident, let alone if there are injuries.
# 4.  **Need for ambulance:** Unknown
# 5.  **Need for firetruck:** Unknown
# 6.  **Need for Police:** Unknown
# 7.  **Types of vehicles involved:** Taxi, sedan (2 possibly SUVs behind)
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, weather appears clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000060.mp4:
# Okay, here's an analysis of the provided frames, based on your request:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Yes (people are exiting one of the vehicles and potentially injured)
# 4.  **Need for ambulance:** Yes (given potential injuries)
# 5.  **Need for firetruck:** No (no visible fire)
# 6.  **Need for Police:** Yes (due to the accident and potential injuries)
# 7.  **Types of vehicles involved:** Sedan, Sedan
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, Wet (roads are wet from the lights)
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000061.mp4:
# Okay, I will analyze the provided frames to the best of my ability and provide the requested information.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Likely Yes
# 4.  **Need for ambulance:** Yes
# 5.  **Need for firetruck:** Yes
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Sedan (Taxi) and Sedan
# 8.  **Fire:** Yes
# 9.  **Day/night and weather:** Night, possibly wet (based on road reflection)
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000062.mp4:
# Okay, I will analyze the images based on your instructions. Here's the information I can gather:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Yes
# 4.  **Need for ambulance:** Yes
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Sedan, Sedan
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, clear
# 10. **Low Res/Bad Footage:** Yes
# Response for 000063.mp4:
# Okay, I will analyze the frames and provide the information you requested. Please remember that this is based solely on the visual information and may not be completely accurate.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Potentially yes (based on the need for emergency services)
# 4.  **Need for ambulance:** Yes (likely, given the police presence and potential for injury)
# 5.  **Need for firetruck:** Possibly (depends on the severity and if there's a fire hazard)
# 6.  **Need for Police:** Yes (police vehicles are present)
# 7.  **Types of vehicles involved:** SUV/Minivan and sedan/car (difficult to specify with certainty)
# 8.  **Fire:** No (no visible flames)
# 9.  **Day/night and weather:** Night, and the weather appears clear
# 10. **Low Res/Bad Footage:** Yes (the resolution is not high, making it hard to identify details clearly)
# Response for 000064.mp4:
# Okay, here's the analysis based on the provided frames:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Unknown (unable to determine from the footage)
# 4.  **Need for ambulance:** Possible (due to the severity of the crash, it's possible)
# 5.  **Need for firetruck:** Unlikely (no visible signs of fire)
# 6.  **Need for Police:** Likely (due to the nature of the accident)
# 7.  **Types of vehicles involved:** Vans
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000065.mp4:
# Okay, I will analyze the frames and provide the requested information.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: unknown
# 4.  Need for ambulance: unknown
# 5.  Need for firetruck: no
# 6.  Need for Police: likely
# 7.  Types of vehicles involved: van, sedan
# 8.  Fire: no
# 9.  Day/night and weather: day, snowy
# 10. Low Res/Bad Footage: no
# Response for 000066.mp4:
# Okay, I will analyze the provided frames to the best of my ability, keeping in mind the low resolution and limitations of this demo:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Unknown.
# 4.  **Need for ambulance:** Possibly, given the accident type.
# 5.  **Need for firetruck:** Possibly, depending on severity and fluid leaks.
# 6.  **Need for Police:** Likely, for accident investigation and report.
# 7.  **Types of vehicles involved:** Appears to be two sedans.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Night, snowy conditions.
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000067.mp4:
# Okay, I will analyze the provided frames and provide the requested information based solely on what is visible in the images.
#
# 1.  **Number of vehicles in accident:** The video contains no accident.
# 2.  **Accident Type:** N/A
# 3.  **Person Injury:** No
# 4.  **Need for ambulance:** No
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** No
# 7.  **Types of vehicles involved:** Sedans, possibly SUV
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, clear weather
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000068.mp4:
# Okay, here's the quantitative information based on the images provided, keeping in mind this is a demo:
#
# 1.  **Number of vehicles in accident:** 4
# 2.  **Accident Type:** Chain reaction/multiple vehicle collision (likely a rear-end type of accident that escalated)
# 3.  **Person Injury:** Likely yes (based on the severity of the crash, it is probable that there were injuries)
# 4.  **Need for ambulance:** Likely yes
# 5.  **Need for firetruck:** Potentially yes (due to the severity of the crash and potential for fuel leaks or other hazards)
# 6.  **Need for Police:** Yes (required for accident investigation and traffic control)
# 7.  **Types of vehicles involved:** SUV, sedan, box truck and dump truck
# 8.  **Fire:** No (no visible signs of fire in the images)
# 9.  **Day/night and weather:** Day, clear
# 10. **Low Res/Bad Footage:** No (footage appears clear and of decent resolution)
#
# **Important Note:** As mentioned, this analysis is based purely on the visual information in the images. A real-world investigation would be needed for definitive answers.
#
# Response for 000069.mp4:
# ...
#
# Response for 000182.mp4:
# Okay, I will do my best to provide the information based solely on the images and your instructions, keeping in mind this is a "demo" and the footage is "low res/bad."
#
# 1.  Number of vehicles in accident: 0
#
# 2.  Accident Type: None Apparent
#
# 3.  Person Injury: Cannot Determine
#
# 4.  Need for ambulance: Cannot Determine
#
# 5.  Need for firetruck: Cannot Determine
#
# 6.  Need for Police: Cannot Determine
#
# 7.  Types of vehicles involved: Sedans, SUVs
#
# 8.  Fire: No
#
# 9.  Day/night and weather: Night, Weather Unknown
#
# 10. Low Res/Bad Footage: Yes
#
# Response for 000183.mp4:
# Okay, I will analyze the video frames based solely on the visual information provided and give you the requested information.
#
# 1.  **Number of vehicles in accident:** It is impossible to determine from this footage.
#
# 2.  **Accident Type:** Unable to determine from these images.
#
# 3.  **Person Injury:** Unable to determine from these images.
#
# 4.  **Need for ambulance:** Unable to determine from these images.
#
# 5.  **Need for firetruck:** Unable to determine from these images.
#
# 6.  **Need for Police:** Unable to determine from these images.
#
# 7.  **Types of vehicles involved:**  SUVs and Sedans are visible.
#
# 8.  **Fire:** No
#
# 9.  **Day/night and weather:** Day, clear weather
#
# 10. **Low Res/Bad Footage:** Yes.
#
# Response for 000184.mp4:
# Okay, I will analyze the provided frames to the best of my ability and provide the requested information based on the visual evidence.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Cannot determine from the image.
# 4.  **Need for ambulance:** Cannot determine from the image.
# 5.  **Need for firetruck:** Cannot determine from the image.
# 6.  **Need for Police:** Cannot determine from the image.
# 7.  **Types of vehicles involved:** SUV, Truck
# 8.  **Fire:** no
# 9.  **Day/night and weather:** Day, Clear
# 10. **Low Res/Bad Footage:** yes
#
# Response for 000185.mp4:
# Okay, I will analyze the frames and provide the requested information.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-bone
# 3.  **Person Injury:** Yes
# 4.  **Need for ambulance:** Yes
# 5.  **Need for firetruck:** Yes
# 6.  **Need for Police:** Yes
# 7.  **Types of vehicles involved:** Car and Truck
# 8.  **Fire:** Yes
# 9.  **Day/night and weather:** Night, looks wet
# 10. **Low Res/Bad Footage:** No
# Response for 000186.mp4:
# Okay, I will analyze the provided frames and provide the information you requested, based solely on what I can observe in the images. Please remember that this is a demo and my analysis is limited by the image quality.
#
# Here's my analysis:
#
# 1.  **Number of vehicles in accident:** 0 (Based on the images, there is no accident occurring)
# 2.  **Accident Type:** Not applicable
# 3.  **Person Injury:** No (Not applicable based on no accident)
# 4.  **Need for ambulance:** No (Not applicable based on no accident)
# 5.  **Need for firetruck:** No (Not applicable based on no accident)
# 6.  **Need for Police:** No (Not applicable based on no accident)
# 7.  **Types of vehicles involved:**  Based on the imagery provided, there are Sedans and trucks passing by.
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, likely wet due to reflections on the road.
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000187.mp4:
# Okay, I will do my best to analyze the provided frames based on your instructions.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: Appears to be a side impact or angled collision.
# 3.  Person Injury: Based on the severity of the crash, it is likely.
# 4.  Need for ambulance: Yes, likely needed.
# 5.  Need for firetruck: Potentially, depending on the severity of the impact and any potential hazards.
# 6.  Need for Police: Yes, for accident investigation and traffic control.
# 7.  Types of vehicles involved: Sedan, Sedan.
# 8.  Fire: No fire visible in the frames.
# 9.  Day/night and weather: Night, Wet Road
# 10. Low Res/Bad Footage: No.
# Response for 000188.mp4:
# Okay, here is the information based on the images provided:
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: Appears to be an intersection collision.
# 3.  Person Injury: likely yes
# 4.  Need for ambulance: likely yes
# 5.  Need for firetruck: possibly
# 6.  Need for Police: likely yes
# 7.  Types of vehicles involved: sedan
# 8.  Fire: no
# 9.  Day/night and weather: night, appears to be clear, but wet roads
# 10. Low Res/Bad Footage: yes
#
# Response for 000189.mp4:
# Here's an analysis of the provided video frames based on your requests:
#
# 1.  **Number of vehicles in accident:** 3
# 2.  **Accident Type:** T-bone collision primarily, with likely secondary impacts.
# 3.  **Person Injury:** Possibly yes. The severity of the impact suggests potential injuries.
# 4.  **Need for ambulance:** Probably yes, given the force of the collision.
# 5.  **Need for firetruck:** Possibly yes, as a precaution.
# 6.  **Need for Police:** Yes, for accident investigation and traffic management.
# 7.  **Types of vehicles involved:** Vans and sedans
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, clear.
# 10. **Low Res/Bad Footage:** Yes, the resolution is low, making it difficult to ascertain detailed damage or specific circumstances.
# Response for 000190.mp4:
# Okay, here's an analysis of the provided images, based solely on what's visible and without any prior context:
#
# 1.  **Number of vehicles in accident:** 0
#
# 2.  **Accident Type:** Not applicable. No accident occurred.
#
# 3.  **Person Injury:** Not applicable. No accident.
#
# 4.  **Need for ambulance:** No.
#
# 5.  **Need for firetruck:** No.
#
# 6.  **Need for Police:** No.
#
# 7.  **Types of vehicles involved:** Motorcycle, Station Wagon, Minivan.
#
# 8.  **Fire:** No.
#
# 9.  **Day/night and weather:** Day, clear.
#
# 10. **Low Res/Bad Footage:** No.
#
# Response for 000191.mp4:
# Okay, here's an analysis of the provided frames, focusing on quantifiable information and answering your specific questions:
#
# 1.  **Number of vehicles in accident:** 3
# 2.  **Accident Type:** T-bone (primarily involving the bus and dark colored sedan)
# 3.  **Person Injury:** Potentially yes (given the severity of a T-bone collision involving a bus and sedan, injuries are likely)
# 4.  **Need for ambulance:** Likely yes (based on the potential for injuries)
# 5.  **Need for firetruck:** Possibly yes (depends on the extent of damage and if there are any hazardous materials involved)
# 6.  **Need for Police:** Yes (given the severity and need to determine fault)
# 7.  **Types of vehicles involved:** Bus, sedan (dark-colored), sedan (red)
# 8.  **Fire:** No (no visual evidence of fire in the frames)
# 9.  **Day/night and weather:** Day, clear weather
# 10. **Low Res/Bad Footage:** Yes (the resolution is low, making it difficult to assess details precisely)
# Response for 000192.mp4:
# Okay, I will analyze the video frames provided and give you the information based on what I can observe.
#
# 1.  **Number of vehicles in accident:** 1
# 2.  **Accident Type:** Single vehicle (appears to be an accident involving only one vehicle)
# 3.  **Person Injury:** Unknown (Difficult to tell from the video)
# 4.  **Need for ambulance:** Unknown
# 5.  **Need for firetruck:** Unknown
# 6.  **Need for Police:** Unknown
# 7.  **Types of vehicles involved:** Sedan
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, appears to be clear
# 10. **Low Res/Bad Footage:** Yes
#
# Response for 000193.mp4:
# Okay, here's an analysis of the provided video based solely on the visual information, and ignoring any previous context:
#
# 1.  Number of vehicles in accident: 1
# 2.  Accident Type: Pedestrian accident
# 3.  Person Injury: Yes
# 4.  Need for ambulance: Yes
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Bus
# 8.  Fire: No
# 9.  Day/night and weather: Day, clear
# 10. Low Res/Bad Footage: No
# Response for 000194.mp4:
# Okay, I will analyze the provided frames and give you the requested information:
#
# 1.  **Number of vehicles in accident:** 0 (Based on the provided frames, there is no visible accident)
# 2.  **Accident Type:** N/A
# 3.  **Person Injury:** No (Based on the lack of visible accident)
# 4.  **Need for ambulance:** No
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** No
# 7.  **Types of vehicles involved:** Motorcycles, vans, cars (sedans and SUVs)
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Clear
# 10. **Low Res/Bad Footage:** Yes, the footage quality is low and grainy.
#
# **Important Note:** This analysis is based solely on the visual information present in the provided frames. If there's additional information not visible in these frames, the analysis could be different.
#
# Response for 000195.mp4:
# Okay, here's an analysis based solely on the single provided image frame:
#
# 1.  **Number of vehicles in accident:** 0 (Based on the single image provided, there is no visible collision or accident occurring)
# 2.  **Accident Type:** Not Applicable (No accident is visible)
# 3.  **Person Injury:** Unknown (Based on the single image provided, there is no visible collision or accident occurring)
# 4.  **Need for ambulance:** No (Based on the single image provided, there is no visible collision or accident occurring)
# 5.  **Need for firetruck:** No (Based on the single image provided, there is no visible collision or accident occurring)
# 6.  **Need for Police:** Unknown (Based on the single image provided, there is no visible collision or accident occurring)
# 7.  **Types of vehicles involved:** Van, Sedan, Minivan, Bus
# 8.  **Fire:** No (Based on the single image provided, there is no visible collision or accident occurring)
# 9.  **Day/night and weather:** Day/Clear
# 10. **Low Res/Bad Footage:** No
#
# Response for 000196.mp4:
# Okay, I'll do my best to analyze these frames with the provided information and instructions.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Potentially yes (based on the nature of the collision)
# 4.  Need for ambulance: Probably yes (based on the nature of the collision)
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Van/Mini-van, Motorcycle
# 8.  Fire: No
# 9.  Day/night and weather: Day, clear
# 10. Low Res/Bad Footage: Yes
# Response for 000197.mp4:
# Okay, here's the analysis based on the provided frames:
#
# 1.  **Number of vehicles in accident:** 1
#
# 2.  **Accident Type:** Single vehicle accident, likely a motorcycle falling over.
#
# 3.  **Person Injury:** Yes, it appears someone is injured as they fell off the motorcycle and others are attending to them.
#
# 4.  **Need for ambulance:** Uncertain, but possibly yes, given the apparent injury.
#
# 5.  **Need for firetruck:** No, fire is not visible and not indicated in the accident type.
#
# 6.  **Need for Police:** Possibly yes, to document the accident and assess any liability.
#
# 7.  **Types of vehicles involved:** Motorcycle/Scooter.
#
# 8.  **Fire:** No.
#
# 9.  **Day/night and weather:** Day, clear weather.
#
# 10. **Low Res/Bad Footage:** No
#
# Response for 000198.mp4:
# Okay, I will analyze the provided frames to provide quantitative information and answer your questions to the best of my ability.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Possible Side Impact (T-Bone) - It appears a motorcycle and another vehicle collided at an intersection or when the motorcycle was attempting a lane change.
# 3.  **Person Injury:** Yes - A person is seen on the ground near the accident.
# 4.  **Need for ambulance:** Yes - Given the presence of a person on the ground, an ambulance is likely needed.
# 5.  **Need for firetruck:** No - There is no visual indication of fire or hazardous materials involved.
# 6.  **Need for Police:** Yes - Accidents involving injuries typically require police investigation for documentation and determination of fault.
# 7.  **Types of vehicles involved:** Motorcycle, Sedan.
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, Clear.
# 10. **Low Res/Bad Footage:** No - The footage is relatively clear.
#
# Response for 000199.mp4:
# Okay, here's the analysis of the potential traffic incident based on the images provided:
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Yes
# 4.  Need for ambulance: Yes
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Sedan, Motorcycle
# 8.  Fire: No
# 9.  Day/night and weather: Day, clear
# 10. Low Res/Bad Footage: No
# Response for 000200.mp4:
# Okay, here's an analysis of the provided video frames based solely on the visual information, adhering to your requested format:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Likely T-bone or side-impact. A red car appears to be impacting a motorcycle.
# 3.  **Person Injury:** Likely yes, due to the nature of motorcycle accidents.
# 4.  **Need for ambulance:** Likely yes, given potential injuries.
# 5.  **Need for firetruck:** Likely no, based on the lack of visible fire or smoke.
# 6.  **Need for Police:** Likely yes, to investigate the accident and determine fault.
# 7.  **Types of vehicles involved:** Sedan (red car) and Motorcycle/Scooter.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Daytime, clear weather.
# 10. **Low Res/Bad Footage:** No, the footage appears to be of reasonable quality for identification.
# Response for 000201.mp4:
# Okay, I will analyze the video frames based on your instructions, focusing on the potential traffic incident.
#
# 1.  **Number of vehicles in accident:** 0
# 2.  **Accident Type:** Not applicable, as there is no accident.
# 3.  **Person Injury:** No
# 4.  **Need for ambulance:** No
# 5.  **Need for firetruck:** No
# 6.  **Need for Police:** No
# 7.  **Types of vehicles involved:** Various sedans, a van, and a small hatchback are visible.
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Day, clear weather
# 10. **Low Res/Bad Footage:** No. The footage appears to be of decent quality.
#
# Response for 000202.mp4:
# Okay, I will analyze the provided frames to give you the requested information about the potential traffic incident.
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** T-Bone
# 3.  **Person Injury:** Uncertain, but possible given the impact.
# 4.  **Need for ambulance:** Likely, given the accident type.
# 5.  **Need for firetruck:** Unlikely based on the visible information.
# 6.  **Need for Police:** Likely, given the nature of the collision to direct traffic and assess fault.
# 7.  **Types of vehicles involved:** Appears to be at least one Sedan or smaller car, and another Vehicle which is harder to discern, but looks like it could be an SUV.
# 8.  **Fire:** No
# 9.  **Day/night and weather:** Night, appears wet or raining based on reflections on the road.
# 10. **Low Res/Bad Footage:** Yes, the footage is grainy and low resolution, making definitive assessment difficult.
#
# Response for 000203.mp4:
# Here's an analysis of the provided frames, focusing on the traffic incident:
#
# 1.  **Number of vehicles in accident:** 2
# 2.  **Accident Type:** Collision between a motorcycle and a car.
# 3.  **Person Injury:** Likely yes. The rider of the motorcycle is seen falling off.
# 4.  **Need for ambulance:** Likely yes, given the potential for injury to the motorcycle rider.
# 5.  **Need for firetruck:** No, there's no indication of fire or need for extrication.
# 6.  **Need for Police:** Yes, to investigate the accident and determine fault.
# 7.  **Types of vehicles involved:** Motorcycle and sedan.
# 8.  **Fire:** No.
# 9.  **Day/night and weather:** Daytime, clear weather.
# 10. **Low Res/Bad Footage:** Yes, the resolution is low, making it difficult to discern finer details.
#
# Response for 000204.mp4:
# Okay, I will analyze the provided frames to identify potential traffic incident details based solely on the visual information.
#
# 1.  Number of vehicles in accident: 2
# 2.  Accident Type: T-bone
# 3.  Person Injury: Yes
# 4.  Need for ambulance: Yes
# 5.  Need for firetruck: No
# 6.  Need for Police: Yes
# 7.  Types of vehicles involved: Sedan and motorcycle
# 8.  Fire: No
# 9.  Day/night and weather: Day/Clear
# 10. Low Res/Bad Footage: Yes
